# %% [markdown]
# # A6 Presentaciones Intermedias

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %ls
# Out:
#  07_02_pie_box_scatter_bubble.ipynb   README.md
# '2019 fantasy.xlsx'                   requierementsEXL
#  Canada.xlsx                          requirements.txt
# 'Clase 4, graficas.ipynb'             runtime.txt
# 'Clase 5.ipynb'                       session_01/
#  datasets/                            welcome_binder.ipynb
#  nhanes_2015_2016.csv

# %%
df = pd.read_excel('2019 fantasy.xlsx',
                   sheet_name = '2019',
                   engine = 'openpyxl')
df
# Out:
#      Unnamed: 0               Player   Tm Pos  Age   G  GS  Cmp  Att   Yds  \
# 0             0  Christian McCaffrey  CAR  RB   23  16  16    0    2     0
# 1             1        Lamar Jackson  BAL  QB   22  15  15  265  401  3127
# 2             2        Derrick Henry  TEN  RB   25  15  15    0    0     0
# 3             3          Aaron Jones  GNB  RB   25  16  16    0    0     0
# 4             4      Ezekiel Elliott  DAL  RB   24  16  16    0    0     0
# ..          ...                  ...  ...  ..  ...  ..  ..  ...  ...   ...
# 615         615      Ray-Ray McCloud  CAR   0   23   6   0    0    0     0
# 616         616     Darrius Shepherd  GNB  WR   24   6   0    0    0     0
# 617         617      Jarrett Stidham  NWE  QB   23   3   0    2    4    14
# 618         618       Michael Walker  JAX  WR   23   7   0    0    0     0
# 619         619        Corey Clement  PHI   0   25   4   0    0    0     0
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Tm', 'Pos', 'Age', 'G', 'GS', 'Cmp', 'Att',
#        'Yds', 'Int', 'Att.1', 'Yds.1', 'Tgt', 'Rec', 'Yds.2', 'Y/R', 'Fumbles',
#        'FumblesLost', 'PassingYds', 'PassingTD', 'PassingAtt', 'RushingYds',
#        'RushingTD', 'RushingAtt', 'ReceivingYds', 'ReceivingTD',
#        'FantasyPoints'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'G', 'GS', 'Att','Yds', 'Att.1', 'Yds.1', 'Rec', 'Yds.2'],
       axis = 1,
       inplace = True)
df.columns
# Out:
# Index(['Player', 'Tm', 'Pos', 'Age', 'Cmp', 'Int', 'Tgt', 'Y/R', 'Fumbles',
#        'FumblesLost', 'PassingYds', 'PassingTD', 'PassingAtt', 'RushingYds',
#        'RushingTD', 'RushingAtt', 'ReceivingYds', 'ReceivingTD',
#        'FantasyPoints'],
#       dtype='object')

# %%
df.set_index('Player', 
             inplace = True)
df
# Out:
#                       Tm Pos  Age  Cmp  Int  Tgt    Y/R  Fumbles  FumblesLost  \
# Player
# Christian McCaffrey  CAR  RB   23    0    0  142   8.66        1            0
# Lamar Jackson        BAL  QB   22  265    6    0   0.00        9            2
# Derrick Henry        TEN  RB   25    0    0   24  11.44        5            3
# Aaron Jones          GNB  RB   25    0    0   68   9.67        3            2
# Ezekiel Elliott      DAL  RB   24    0    0   71   7.78        3            2
# ...                  ...  ..  ...  ...  ...  ...    ...      ...          ...
# Ray-Ray McCloud      CAR   0   23    0    0    0   0.00        3            1
# Darrius Shepherd     GNB  WR   24    0    0    2   1.00        1            1
# Jarrett Stidham      NWE  QB   23    2    1    0   0.00        0            0
# Michael Walker       JAX  WR   23    0    0    3   7.50        2            2
# Corey Clement        PHI   0   25    0    0    0   0.00        2            2
#
# ...

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
df.rename(columns = {'Tm':'Team',
                     'Pos':'Position'},
          inplace = True)
df
# Out:
#                     Team Position  Age  Cmp  Int  Tgt    Y/R  Fumbles  \
# Player
# Christian McCaffrey  CAR       RB   23    0    0  142   8.66        1
# Lamar Jackson        BAL       QB   22  265    6    0   0.00        9
# Derrick Henry        TEN       RB   25    0    0   24  11.44        5
# Aaron Jones          GNB       RB   25    0    0   68   9.67        3
# Ezekiel Elliott      DAL       RB   24    0    0   71   7.78        3
# ...                  ...      ...  ...  ...  ...  ...    ...      ...
# Ray-Ray McCloud      CAR        0   23    0    0    0   0.00        3
# Darrius Shepherd     GNB       WR   24    0    0    2   1.00        1
# Jarrett Stidham      NWE       QB   23    2    1    0   0.00        0
# Michael Walker       JAX       WR   23    0    0    3   7.50        2
# Corey Clement        PHI        0   25    0    0    0   0.00        2
#
#                      FumblesLost  PassingYds  PassingTD  PassingAtt  \
# Player
# ...

# %%
histogram = df['Age'].plot(kind='hist')

# %%
pd.value_counts(df['Position'])
# Out:
# WR    217
# RB    153
# TE    116
# QB     71
# 0      63
# Name: Position, dtype: int64

# %%
#Tabla de Frecuencias
100 * df['Position'].value_counts() / len(df['Position'])
# Out:
# WR    35.000000
# RB    24.677419
# TE    18.709677
# QB    11.451613
# 0     10.161290
# Name: Position, dtype: float64

# %%
# Gráfico de barras de posiciones de los jugadores
plot = df['Position'].value_counts().plot(kind='bar',
                                            title='Posiciones de los jugadores')
