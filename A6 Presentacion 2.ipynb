# %% [markdown]
# # A6 Presentacion

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %ls
# Out:
#  07_02_pie_box_scatter_bubble.ipynb   nhanes_2015_2016.csv
# '2019 fantasy.xlsx'                   README.md
# 'A6 Presentaciones.ipynb'             requierementsEXL
#  Canada.xlsx                          requirements.txt
# 'Clase 4, graficas.ipynb'             runtime.txt
# 'Clase 5.ipynb'                       session_01/
#  datasets/                            welcome_binder.ipynb

# %%
df = pd.read_excel('2019 fantasy.xlsx',
                   sheet_name = '2019',
                   engine = 'openpyxl')
df
# Out:
#      Unnamed: 0               Player   Tm Pos  Age   G  GS  Cmp  Att   Yds  \
# 0             0  Christian McCaffrey  CAR  RB   23  16  16    0    2     0
# 1             1        Lamar Jackson  BAL  QB   22  15  15  265  401  3127
# 2             2        Derrick Henry  TEN  RB   25  15  15    0    0     0
# 3             3          Aaron Jones  GNB  RB   25  16  16    0    0     0
# 4             4      Ezekiel Elliott  DAL  RB   24  16  16    0    0     0
# ..          ...                  ...  ...  ..  ...  ..  ..  ...  ...   ...
# 615         615      Ray-Ray McCloud  CAR   0   23   6   0    0    0     0
# 616         616     Darrius Shepherd  GNB  WR   24   6   0    0    0     0
# 617         617      Jarrett Stidham  NWE  QB   23   3   0    2    4    14
# 618         618       Michael Walker  JAX  WR   23   7   0    0    0     0
# 619         619        Corey Clement  PHI   0   25   4   0    0    0     0
#
#      ...  FumblesLost  PassingYds  PassingTD  PassingAtt  RushingYds  \
# 0    ...            0           0          0           2        1387
# 1    ...            2        3127         36         401        1206
# 2    ...            3           0          0           0        1540
# 3    ...            2           0          0           0        1084
# 4    ...            2           0          0           0        1357
# ..   ...          ...         ...        ...         ...         ...
# 615  ...            1           0          0           0           0
# 616  ...            1           0          0           0           0
# 617  ...            0          14          0           4          -2
# 618  ...            2           0          0           0           0
# 619  ...            2           0          0           0           0
#
#      RushingTD  RushingAtt  ReceivingYds  ReceivingTD  FantasyPoints
# 0           15         287          1005            4         469.20
# 1            7         176             0            0         415.68
# 2           16         303           206            2         294.60
# 3           16         236           474            3         314.80
# 4           12         301           420            2         311.70
# ..         ...         ...           ...          ...            ...
# 615          0           0             0            0          -2.00
# 616          0           0             1            0          -0.90
# 617          0           2             0            0          -1.64
# 618          0           0            15            0          -0.50
# 619          0           0             0            0          -4.00
#
# [620 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Tm', 'Pos', 'Age', 'G', 'GS', 'Cmp', 'Att',
#        'Yds', 'Int', 'Att.1', 'Yds.1', 'Tgt', 'Rec', 'Yds.2', 'Y/R', 'Fumbles',
#        'FumblesLost', 'PassingYds', 'PassingTD', 'PassingAtt', 'RushingYds',
#        'RushingTD', 'RushingAtt', 'ReceivingYds', 'ReceivingTD',
#        'FantasyPoints'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'G', 'GS', 'Att','Yds', 'Att.1', 'Yds.1', 'Yds.2'],
       axis = 1,
       inplace = True)
df.columns
# Out:
# Index(['Player', 'Tm', 'Pos', 'Age', 'Cmp', 'Int', 'Tgt', 'Rec', 'Y/R',
#        'Fumbles', 'FumblesLost', 'PassingYds', 'PassingTD', 'PassingAtt',
#        'RushingYds', 'RushingTD', 'RushingAtt', 'ReceivingYds', 'ReceivingTD',
#        'FantasyPoints'],
#       dtype='object')

# %%
df.set_index('Player', 
             inplace = True)
df
# Out:
#                       Tm Pos  Age  Cmp  Int  Tgt  Rec    Y/R  Fumbles  \
# Player
# Christian McCaffrey  CAR  RB   23    0    0  142  116   8.66        1
# Lamar Jackson        BAL  QB   22  265    6    0    0   0.00        9
# Derrick Henry        TEN  RB   25    0    0   24   18  11.44        5
# Aaron Jones          GNB  RB   25    0    0   68   49   9.67        3
# Ezekiel Elliott      DAL  RB   24    0    0   71   54   7.78        3
# ...                  ...  ..  ...  ...  ...  ...  ...    ...      ...
# Ray-Ray McCloud      CAR   0   23    0    0    0    0   0.00        3
# Darrius Shepherd     GNB  WR   24    0    0    2    1   1.00        1
# Jarrett Stidham      NWE  QB   23    2    1    0    0   0.00        0
# Michael Walker       JAX  WR   23    0    0    3    2   7.50        2
# Corey Clement        PHI   0   25    0    0    0    0   0.00        2
#
#                      FumblesLost  PassingYds  PassingTD  PassingAtt  \
# Player
# Christian McCaffrey            0           0          0           2
# Lamar Jackson                  2        3127         36         401
# Derrick Henry                  3           0          0           0
# Aaron Jones                    2           0          0           0
# Ezekiel Elliott                2           0          0           0
# ...                          ...         ...        ...         ...
# Ray-Ray McCloud                1           0          0           0
# Darrius Shepherd               1           0          0           0
# Jarrett Stidham                0          14          0           4
# Michael Walker                 2           0          0           0
# Corey Clement                  2           0          0           0
#
#                      RushingYds  RushingTD  RushingAtt  ReceivingYds  \
# Player
# Christian McCaffrey        1387         15         287          1005
# Lamar Jackson              1206          7         176             0
# Derrick Henry              1540         16         303           206
# Aaron Jones                1084         16         236           474
# Ezekiel Elliott            1357         12         301           420
# ...                         ...        ...         ...           ...
# Ray-Ray McCloud               0          0           0             0
# Darrius Shepherd              0          0           0             1
# Jarrett Stidham              -2          0           2             0
# Michael Walker                0          0           0            15
# Corey Clement                 0          0           0             0
#
#                      ReceivingTD  FantasyPoints
# Player
# Christian McCaffrey            4         469.20
# Lamar Jackson                  0         415.68
# Derrick Henry                  2         294.60
# Aaron Jones                    3         314.80
# Ezekiel Elliott                2         311.70
# ...                          ...            ...
# Ray-Ray McCloud                0          -2.00
# Darrius Shepherd               0          -0.90
# Jarrett Stidham                0          -1.64
# Michael Walker                 0          -0.50
# Corey Clement                  0          -4.00
#
# [620 rows x 19 columns]

# %%
df.rename(columns = {'Tm':'Team',
                     'Pos':'Position'},
          inplace = True)
df
# Out:
#                     Team Position  Age  Cmp  Int  Tgt  Rec    Y/R  Fumbles  \
# Player
# Christian McCaffrey  CAR       RB   23    0    0  142  116   8.66        1
# Lamar Jackson        BAL       QB   22  265    6    0    0   0.00        9
# Derrick Henry        TEN       RB   25    0    0   24   18  11.44        5
# Aaron Jones          GNB       RB   25    0    0   68   49   9.67        3
# Ezekiel Elliott      DAL       RB   24    0    0   71   54   7.78        3
# ...                  ...      ...  ...  ...  ...  ...  ...    ...      ...
# Ray-Ray McCloud      CAR        0   23    0    0    0    0   0.00        3
# Darrius Shepherd     GNB       WR   24    0    0    2    1   1.00        1
# Jarrett Stidham      NWE       QB   23    2    1    0    0   0.00        0
# Michael Walker       JAX       WR   23    0    0    3    2   7.50        2
# Corey Clement        PHI        0   25    0    0    0    0   0.00        2
#
#                      FumblesLost  PassingYds  PassingTD  PassingAtt  \
# Player
# Christian McCaffrey            0           0          0           2
# Lamar Jackson                  2        3127         36         401
# Derrick Henry                  3           0          0           0
# Aaron Jones                    2           0          0           0
# Ezekiel Elliott                2           0          0           0
# ...                          ...         ...        ...         ...
# Ray-Ray McCloud                1           0          0           0
# Darrius Shepherd               1           0          0           0
# Jarrett Stidham                0          14          0           4
# Michael Walker                 2           0          0           0
# Corey Clement                  2           0          0           0
#
#                      RushingYds  RushingTD  RushingAtt  ReceivingYds  \
# Player
# Christian McCaffrey        1387         15         287          1005
# Lamar Jackson              1206          7         176             0
# Derrick Henry              1540         16         303           206
# Aaron Jones                1084         16         236           474
# Ezekiel Elliott            1357         12         301           420
# ...                         ...        ...         ...           ...
# Ray-Ray McCloud               0          0           0             0
# Darrius Shepherd              0          0           0             1
# Jarrett Stidham              -2          0           2             0
# Michael Walker                0          0           0            15
# Corey Clement                 0          0           0             0
#
#                      ReceivingTD  FantasyPoints
# Player
# Christian McCaffrey            4         469.20
# Lamar Jackson                  0         415.68
# Derrick Henry                  2         294.60
# Aaron Jones                    3         314.80
# Ezekiel Elliott                2         311.70
# ...                          ...            ...
# Ray-Ray McCloud                0          -2.00
# Darrius Shepherd               0          -0.90
# Jarrett Stidham                0          -1.64
# Michael Walker                 0          -0.50
# Corey Clement                  0          -4.00
#
# [620 rows x 19 columns]

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 620 entries, Christian McCaffrey to Corey Clement
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Team           620 non-null    object
#  1   Position       620 non-null    object
#  2   Age            620 non-null    int64
#  3   Cmp            620 non-null    int64
#  4   Int            620 non-null    int64
#  5   Tgt            620 non-null    int64
#  6   Rec            620 non-null    int64
#  7   Y/R            620 non-null    float64
#  8   Fumbles        620 non-null    int64
#  9   FumblesLost    620 non-null    int64
#  10  PassingYds     620 non-null    int64
#  11  PassingTD      620 non-null    int64
#  12  PassingAtt     620 non-null    int64
#  13  RushingYds     620 non-null    int64
#  14  RushingTD      620 non-null    int64
#  15  RushingAtt     620 non-null    int64
#  16  ReceivingYds   620 non-null    int64
#  17  ReceivingTD    620 non-null    int64
#  18  FantasyPoints  620 non-null    float64
# dtypes: float64(2), int64(15), object(2)
# memory usage: 96.9+ KB

# %%
df.describe()
# Out:
#               Age        Cmp         Int         Tgt         Rec         Y/R  \
# count  620.000000  620.00000  620.000000  620.000000  620.000000  620.000000
# mean    26.008065   18.26129    0.658065   27.598387   18.237097    8.221177
# std      3.406010   70.31567    2.704484   35.801621   24.122739    6.297130
# min     21.000000    0.00000    0.000000    0.000000    0.000000   -4.000000
# 25%     24.000000    0.00000    0.000000    1.000000    1.000000    2.330000
# 50%     25.000000    0.00000    0.000000   12.000000    8.000000    8.635000
# 75%     27.000000    0.00000    0.000000   43.000000   29.250000   12.170000
# max     42.000000  408.00000   30.000000  185.000000  149.000000   38.330000
#
#           Fumbles  FumblesLost   PassingYds   PassingTD  PassingAtt  \
# count  620.000000   620.000000   620.000000  620.000000  620.000000
# mean     0.969355     0.467742   207.772581    1.283871   28.772581
# std      2.164636     1.059121   808.348110    5.180746  110.033237
# min      0.000000     0.000000     0.000000    0.000000    0.000000
# 25%      0.000000     0.000000     0.000000    0.000000    0.000000
# 50%      0.000000     0.000000     0.000000    0.000000    0.000000
# 75%      1.000000     1.000000     0.000000    0.000000    0.000000
# max     18.000000    11.000000  5109.000000   36.000000  626.000000
#
#         RushingYds   RushingTD  RushingAtt  ReceivingYds  ReceivingTD  \
# count   620.000000  620.000000  620.000000    620.000000   620.000000
# mean     93.114516    0.720968   21.572581    207.674194     1.270968
# std     237.415816    2.032342   52.994402    299.258611     2.097956
# min     -12.000000    0.000000    0.000000     -4.000000     0.000000
# 25%       0.000000    0.000000    0.000000      3.000000     0.000000
# 50%       0.000000    0.000000    1.000000     71.500000     0.000000
# 75%      40.250000    0.000000   10.000000    286.250000     2.000000
# max    1540.000000   16.000000  303.000000   1725.000000    11.000000
#
#        FantasyPoints
# count     620.000000
# mean       71.462355
# std        85.064593
# min        -4.000000
# 25%         5.650000
# 50%        35.500000
# 75%       108.950000
# max       469.200000

# %% [markdown]
# ## ¿Cual es la edad en la que la mayoría de los jugadores se encuentra?

# %%
histogram = df['Age'].plot(kind='hist',
                          title = 'Edades')

# %%
pd.value_counts(df['Position'])
# Out:
# WR    217
# RB    153
# TE    116
# QB     71
# 0      63
# Name: Position, dtype: int64

# %%
#Tabla de Frecuencias
100 * df['Position'].value_counts() / len(df['Position'])
# Out:
# WR    35.000000
# RB    24.677419
# TE    18.709677
# QB    11.451613
# 0     10.161290
# Name: Position, dtype: float64

# %% [markdown]
# ## ¿Cuál es la posición en la que la mayoría de jugadores está?

# %%
# Gráfico de barras de posiciones de los jugadores
plot = df['Position'].value_counts().plot(kind='bar',
                                            title='Posiciones de los jugadores')

# %% [markdown]
# ## Relación entre los puntos y la edad

# %%
sns.lmplot(x = 'Age',
          y = 'FantasyPoints',
           data = df,
          fit_reg = True)
plt.title('Scatter Plot of Age vs Fantasy Points')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Fantasy Points')
